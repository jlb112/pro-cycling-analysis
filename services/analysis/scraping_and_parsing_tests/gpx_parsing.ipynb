# %%
import os
import gpxpy
import xml.etree.ElementTree as ET
import pandas as pd
import numpy as np
from haversine import haversine, Unit

# %%
# Directory containing GPX files
gpx_dir = "data/gpx_files"
output_dir = "data/gpx_parsed"

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Function to calculate haversine distance
def haversine_distance(lat1, lon1, lat2, lon2):
    return haversine((lat1, lon1), (lat2, lon2), unit=Unit.METERS)

# Function to parse metadata using ElementTree
def parse_metadata(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    namespace = {"default": "http://www.topografix.com/GPX/1/1"}

    # Extract link
    link = root.find("default:metadata/default:author/default:link", namespace)
    link = link.attrib["href"] if link is not None else "No link"

    return link

#Avoids haversine package
def fast_haversine_np(df):
    lat = np.radians(df["latitude"].to_numpy())
    lon = np.radians(df["longitude"].to_numpy())
    
    dlat = lat[1:] - lat[:-1]
    dlon = lon[1:] - lon[:-1]

    a = np.sin(dlat / 2.0) ** 2 + np.cos(lat[:-1]) * np.cos(lat[1:]) * np.sin(dlon / 2.0) ** 2
    c = 2 * np.arcsin(np.sqrt(a))
    R = 6371000  # Earth radius in meters
    dist = R * c

    return np.insert(dist, 0, 0)

# Function to parse a single GPX file and calculate derived fields
def parse_gpx_file(file_path):
    
    # Extract the file name (without extension) as the name
    name = os.path.splitext(os.path.basename(file_path))[0]
    # Parse metadata
    link = parse_metadata(file_path)

    # Parse track points using gpxpy
    with open(file_path, 'r') as gpx_file:
        gpx = gpxpy.parse(gpx_file)

    route_info = []
    for track in gpx.tracks:
        for segment in track.segments:
            for point in segment.points:
                route_info.append({
                    "latitude": point.latitude,
                    "longitude": point.longitude,
                    "elevation": point.elevation,
                    "time": point.time,
                    "name": name,
                    "link": link
                })

    # Convert to DataFrame
    route_df = pd.DataFrame(route_info)

    
    route_df["distance"] = fast_haversine_np(route_df)
    # Calculate elevation difference
    route_df['elevation_diff'] = route_df['elevation'].diff().fillna(0)

    # Calculate cumulative elevation and cumulative distance
    route_df['cum_elevation'] = route_df['elevation_diff'].cumsum()
    route_df['cum_distance'] = route_df['distance'].cumsum()

    return route_df

# %%
# Iterate over all GPX files in the directory
for file_name in os.listdir(gpx_dir):
    if file_name.endswith("2019 SKODA Tour de Luxembourg Stage 4.gpx"):
        file_path = os.path.join(gpx_dir, file_name)
        print(f"Processing {file_name}...")

        # Parse the GPX file and calculate derived fields
        df = parse_gpx_file(file_path)

        # Export to CSV
        output_file = os.path.join(output_dir, f"{os.path.splitext(file_name)[0]}.csv")
        df.to_csv(output_file, index=False)
        print(f"Saved to {output_file}")

print("All GPX files have been processed.")
# Out:
# Processing 2019 SKODA Tour de Luxembourg Stage 4.gpx...
# Saved to data/gpx_parsed\2019 SKODA Tour de Luxembourg Stage 4.csv
# All GPX files have been processed.

# %%
# Iterate over all GPX files in the directory
for file_name in os.listdir(gpx_dir):
    if file_name.endswith(".gpx"):
        file_path = os.path.join(gpx_dir, file_name)

        # Check if the corresponding CSV file already exists
        output_file = os.path.join(output_dir, f"{os.path.splitext(file_name)[0]}.csv")
        if os.path.exists(output_file):
            print(f"Skipping {file_name}, already processed.")
            continue  # Skip the file if it's already processed

        print(f"Processing {file_name}...")

        # Parse the GPX file and calculate derived fields
        df = parse_gpx_file(file_path)

        # Export to CSV
        output_file = os.path.join(output_dir, f"{os.path.splitext(file_name)[0]}.csv")
        df.to_csv(output_file, index=False)
        print(f"Saved to {output_file}")

print("All GPX files have been processed.")
# Out:
# Skipping 2017 4 Jours de Dunkerque .gpx, already processed.
# Skipping 2017 99a Coppa Bernocchi - 42o GP BPM.gpx, already processed.
# Skipping 2017 Abu Dhabi Tour Stage 1.gpx, already processed.
# Skipping 2017 Abu Dhabi Tour Stage 2.gpx, already processed.
# Skipping 2017 Abu Dhabi Tour Stage 3.gpx, already processed.
# Skipping 2017 Abu Dhabi Tour Stage 4.gpx, already processed.
# Skipping 2017 ACC Asian Road Championships - ITT.gpx, already processed.
# Skipping 2017 ACC Asian Road Championships - TTT.gpx, already processed.
# Skipping 2017 ACC Asian Road Championships.gpx, already processed.
# Skipping 2017 Amgen Tour of California Stage 1.gpx, already processed.
# Skipping 2017 Amgen Tour of California Stage 2.gpx, already processed.
# Skipping 2017 Amgen Tour of California Stage 3.gpx, already processed.
# Skipping 2017 Amgen Tour of California Stage 4.gpx, already processed.
# Skipping 2017 Amgen Tour of California Stage 5.gpx, already processed.
# Skipping 2017 Amgen Tour of California Stage 6.gpx, already processed.
# Skipping 2017 Amgen Tour of California Stage 7.gpx, already processed.
# Skipping 2017 Amstel Gold Race.gpx, already processed.
# Skipping 2017 Arctic Race of Norway Stage 1.gpx, already processed.
# Skipping 2017 Arctic Race of Norway Stage 2.gpx, already processed.
# Skipping 2017 Arctic Race of Norway Stage 3.gpx, already processed.
# Skipping 2017 Arctic Race of Norway Stage 4.gpx, already processed.
# Skipping 2017 Arnhem-Veenendaal Classic.gpx, already processed.
# Skipping 2017 Australian Road National Championships - ITT.gpx, already processed.
# Skipping 2017 Australian Road National Championships.gpx, already processed.
# Skipping 2017 Austrian Road National Championships - ITT.gpx, already processed.
# Skipping 2017 Austrian Road National Championships.gpx, already processed.
# Skipping 2017 Baloise Belgium Tour Stage 1.gpx, already processed.
# Skipping 2017 Baloise Belgium Tour Stage 2.gpx, already processed.
# Skipping 2017 Baloise Belgium Tour Stage 3.gpx, already processed.
# Skipping 2017 Baloise Belgium Tour Stage 4.gpx, already processed.
# Skipping 2017 Baloise Belgium Tour Stage 5.gpx, already processed.
# Skipping 2017 Belgian Road National Championships - ITT.gpx, already processed.
# Skipping 2017 Belgian Road National Championships.gpx, already processed.
# Skipping 2017 BeNe Ladies Tour Prologue.gpx, already processed.
# Skipping 2017 BeNe Ladies Tour Stage 1.gpx, already processed.
# Skipping 2017 BeNe Ladies Tour Stage 2-1.gpx, already processed.
# Skipping 2017 BeNe Ladies Tour Stage 2-2.gpx, already processed.
# Skipping 2017 BeNe Ladies Tour Stage 3.gpx, already processed.
# Skipping 2017 Binche - Chimay - Binche (Memorial Frank Vandenbroucke).gpx, already processed.
# Skipping 2017 BinckBank Tour Stage 1.gpx, already processed.
# Skipping 2017 BinckBank Tour Stage 2.gpx, already processed.
# Skipping 2017 BinckBank Tour Stage 3.gpx, already processed.
# Skipping 2017 BinckBank Tour Stage 4.gpx, already processed.
# Skipping 2017 BinckBank Tour Stage 5.gpx, already processed.
# Skipping 2017 BinckBank Tour Stage 6.gpx, already processed.
# Skipping 2017 BinckBank Tour Stage 7.gpx, already processed.
# Skipping 2017 Boels Rentals Ladies Tour Prologue.gpx, already processed.
# Skipping 2017 Boels Rentals Ladies Tour Stage 1.gpx, already processed.
# Skipping 2017 Boels Rentals Ladies Tour Stage 2.gpx, already processed.
# Skipping 2017 Boels Rentals Ladies Tour Stage 3.gpx, already processed.
# Skipping 2017 Boels Rentals Ladies Tour Stage 4.gpx, already processed.
# Skipping 2017 Boels Rentals Ladies Tour Stage 5.gpx, already processed.
# Skipping 2017 Boucles de l'Aulne - Chateaulin.gpx, already processed.
# Skipping 2017 Boucles de la Mayenne Prologue.gpx, already processed.
# Skipping 2017 Boucles de la Mayenne Stage 1.gpx, already processed.
# Skipping 2017 Boucles de la Mayenne Stage 2.gpx, already processed.
# Skipping 2017 Boucles de la Mayenne Stage 3.gpx, already processed.
# Skipping 2017 Bretagne Classic - Ouest France.gpx, already processed.
# Skipping 2017 British Road National Championships - ITT.gpx, already processed.
# Skipping 2017 British Road National Championships.gpx, already processed.
# Skipping 2017 Brussels Cycling Classic.gpx, already processed.
# Skipping 2017 CAC African Road Championships - ITT.gpx, already processed.
# Skipping 2017 CAC African Road Championships - TTT.gpx, already processed.
# Skipping 2017 CAC African Road Championships.gpx, already processed.
# Skipping 2017 Cadel Evans Great Ocean Road Race - Albert Park Grand Prix.gpx, already processed.
# Skipping 2017 Cadel Evans Great Ocean Road Race.gpx, already processed.
# Skipping 2017 Canadian Road National Championships - ITT.gpx, already processed.
# Skipping 2017 Canadian Road National Championships.gpx, already processed.
# Skipping 2017 Carrefour Market Heistse Pijl.gpx, already processed.
# Skipping 2017 Chrono des Nations.gpx, already processed.
# Skipping 2017 Circuit Cycliste Sarthe - Pays de la Loire Stage 1.gpx, already processed.
# Skipping 2017 Circuit Cycliste Sarthe - Pays de la Loire Stage 2-1.gpx, already processed.
# Skipping 2017 Circuit Cycliste Sarthe - Pays de la Loire Stage 2-2.gpx, already processed.
# Skipping 2017 Circuit Cycliste Sarthe - Pays de la Loire Stage 3.gpx, already processed.
# Skipping 2017 Circuit Cycliste Sarthe - Pays de la Loire Stage 4.gpx, already processed.
# Skipping 2017 Circuito de Getxo - Memorial Ricardo Otxoa.gpx, already processed.
# Skipping 2017 Clasica Ciclista San Sebastian.gpx, already processed.
# Skipping 2017 Clasica de Almeria.gpx, already processed.
# Skipping 2017 Classic Loire Atlantique.gpx, already processed.
# Skipping 2017 Colombian Road National Championships - ITT.gpx, already processed.
# Skipping 2017 Colombian Road National Championships.gpx, already processed.
# Skipping 2017 Colorado Classic Stage 1.gpx, already processed.
# Skipping 2017 Colorado Classic Stage 2.gpx, already processed.
# Skipping 2017 Colorado Classic Stage 3.gpx, already processed.
# Skipping 2017 Colorado Classic Stage 4.gpx, already processed.
# Skipping 2017 COPACI Campeonato Panamericano de Ruta - ITT.gpx, already processed.
# Skipping 2017 COPACI Campeonato Panamericano de Ruta.gpx, already processed.
# Skipping 2017 Coppa Agostoni - Giro delle Brianze.gpx, already processed.
# Skipping 2017 Coppa Sabatini.gpx, already processed.
# Skipping 2017 Crescent Vargarda TTT.gpx, already processed.
# Skipping 2017 Crescent Vargarda.gpx, already processed.
# Skipping 2017 Criterium du Dauphine Stage 1.gpx, already processed.
# Skipping 2017 Criterium du Dauphine Stage 2.gpx, already processed.
# Skipping 2017 Criterium du Dauphine Stage 3.gpx, already processed.
# Skipping 2017 Criterium du Dauphine Stage 4.gpx, already processed.
# Skipping 2017 Criterium du Dauphine Stage 5.gpx, already processed.
# Skipping 2017 Criterium du Dauphine Stage 6.gpx, already processed.
# Skipping 2017 Criterium du Dauphine Stage 7.gpx, already processed.
# Skipping 2017 Criterium du Dauphine Stage 8.gpx, already processed.
# Skipping 2017 Czech Cycling Tour Stage 1.gpx, already processed.
# Skipping 2017 Czech Cycling Tour Stage 2.gpx, already processed.
# Skipping 2017 Czech Cycling Tour Stage 3.gpx, already processed.
# Skipping 2017 Czech Cycling Tour Stage 4.gpx, already processed.
# Skipping 2017 Czech Republic Road National Championships - ITT.gpx, already processed.
# Skipping 2017 Czech Republic Road National Championships.gpx, already processed.
# Skipping 2017 Danilith - Nokere Koerse.gpx, already processed.
# Skipping 2017 Danish Road National Championships - ITT.gpx, already processed.
# Skipping 2017 Danish Road National Championships.gpx, already processed.
# Skipping 2017 De Brabantse Pijl - La Fleche Brabanconne.gpx, already processed.
# Skipping 2017 Driedaagse De Panne - Koksijde Stage 1.gpx, already processed.
# Skipping 2017 Driedaagse De Panne - Koksijde Stage 2.gpx, already processed.
# Skipping 2017 Driedaagse De Panne - Koksijde Stage 3-1.gpx, already processed.
# Skipping 2017 Driedaagse De Panne - Koksijde Stage 3-2.gpx, already processed.
# Skipping 2017 Druivenkoers - Overijse.gpx, already processed.
# Skipping 2017 Dubai Tour Stage 1.gpx, already processed.
# Skipping 2017 Dubai Tour Stage 2.gpx, already processed.
# Skipping 2017 Dubai Tour Stage 3.gpx, already processed.
# Skipping 2017 Dubai Tour Stage 4.gpx, already processed.
# Skipping 2017 Dubai Tour Stage 5.gpx, already processed.
# Skipping 2017 Duo Normand.gpx, already processed.
# Skipping 2017 Dwars door de Westhoek.gpx, already processed.
# Skipping 2017 Dwars door het Hageland - Aarschot.gpx, already processed.
# Skipping 2017 Dwars Door Vlaanderen .gpx, already processed.
# Skipping 2017 Dwars door West-Vlaanderen - Johan Museeuw Classic.gpx, already processed.
# Skipping 2017 Elfstedenronde (Bruges Cycling Classic).gpx, already processed.
# Skipping 2017 Emakumeen XXX. Bira Stage 1.gpx, already processed.
# Skipping 2017 Emakumeen XXX. Bira Stage 2.gpx, already processed.
# Skipping 2017 Emakumeen XXX. Bira Stage 3.gpx, already processed.
# Skipping 2017 Emakumeen XXX. Bira Stage 4.gpx, already processed.
# Skipping 2017 Emakumeen XXX. Bira Stage 5.gpx, already processed.
# Skipping 2017 EPZ Omloop van Borsele.gpx, already processed.
# Skipping 2017 Eschborn-Frankfurt 'Rund um den Finanzplatz'.gpx, already processed.
# Skipping 2017 Etoile de Besseges Stage 1.gpx, already processed.
# Skipping 2017 Etoile de Besseges Stage 2.gpx, already processed.
# Skipping 2017 Etoile de Besseges Stage 3.gpx, already processed.
# Skipping 2017 Etoile de Besseges Stage 4.gpx, already processed.
# Skipping 2017 Etoile de Besseges Stage 5.gpx, already processed.
# Skipping 2017 Euroeyes Cyclassics.gpx, already processed.
# Skipping 2017 Famenne Ardenne Classic.gpx, already processed.
# Skipping 2017 Faun Environnement - Classic de l'Ardeche Rhone Crussol.gpx, already processed.
# Skipping 2017 Festival Elsy Jacobs Prologue.gpx, already processed.
# Skipping 2017 Festival Elsy Jacobs Stage 1.gpx, already processed.
# Skipping 2017 Festival Elsy Jacobs Stage 2.gpx, already processed.
# Skipping 2017 French Road National Championships - ITT.gpx, already processed.
# Skipping 2017 French Road National Championships.gpx, already processed.
# Skipping 2017 Gent-Wevelgem in Flanders Fields.gpx, already processed.
# Skipping 2017 German Road National Championships - ITT.gpx, already processed.
# Skipping 2017 German Road National Championships.gpx, already processed.
# Skipping 2017 Giro Ciclistico d'Italia Stage 1.gpx, already processed.
# Skipping 2017 Giro Ciclistico d'Italia Stage 2.gpx, already processed.
# Skipping 2017 Giro Ciclistico d'Italia Stage 3.gpx, already processed.
# Skipping 2017 Giro Ciclistico d'Italia Stage 4.gpx, already processed.
# Skipping 2017 Giro Ciclistico d'Italia Stage 5-1.gpx, already processed.
# Skipping 2017 Giro Ciclistico d'Italia Stage 5-2.gpx, already processed.
# Skipping 2017 Giro Ciclistico d'Italia Stage 6.gpx, already processed.
# Skipping 2017 Giro Ciclistico d'Italia Stage 7.gpx, already processed.
# Skipping 2017 Giro d'Italia Femminile Internazionale Stage 1.gpx, already processed.
# Skipping 2017 Giro d'Italia Femminile Internazionale Stage 10.gpx, already processed.
# Skipping 2017 Giro d'Italia Femminile Internazionale Stage 2.gpx, already processed.
# Skipping 2017 Giro d'Italia Femminile Internazionale Stage 3.gpx, already processed.
# Skipping 2017 Giro d'Italia Femminile Internazionale Stage 4.gpx, already processed.
# Skipping 2017 Giro d'Italia Femminile Internazionale Stage 5.gpx, already processed.
# Skipping 2017 Giro d'Italia Femminile Internazionale Stage 6.gpx, already processed.
# Skipping 2017 Giro d'Italia Femminile Internazionale Stage 7.gpx, already processed.
# Skipping 2017 Giro d'Italia Femminile Internazionale Stage 8.gpx, already processed.
# Skipping 2017 Giro d'Italia Femminile Internazionale Stage 9.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 1.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 10.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 11.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 12.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 13.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 14.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 15.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 16.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 17.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 18.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 19.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 2.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 20.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 21.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 3.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 4.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 5.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 6.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 7.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 8.gpx, already processed.
# Skipping 2017 Giro d'Italia Stage 9.gpx, already processed.
# Skipping 2017 Giro del Trentino Alto Adige - Sudtirol.gpx, already processed.
# Skipping 2017 Giro dell'Appennino.gpx, already processed.
# Skipping 2017 Giro dell'Emilia Internazionale Donne Elite.gpx, already processed.
# Skipping 2017 Giro dell'Emilia.gpx, already processed.
# Skipping 2017 Giro della Toscana Stage 1.gpx, already processed.
# Skipping 2017 Giro della Toscana Stage 2.gpx, already processed.
# Skipping 2017 GP Beiras e Serra da Estrela Stage 1.gpx, already processed.
# Skipping 2017 GP Beiras e Serra da Estrela Stage 2.gpx, already processed.
# Skipping 2017 GP Beiras e Serra da Estrela Stage 3.gpx, already processed.
# Skipping 2017 GP de Denain - Porte du Hainaut .gpx, already processed.
# Skipping 2017 GP de Fourmies .gpx, already processed.
# Skipping 2017 GP de Plouay - Lorient Agglomeration.gpx, already processed.
# Skipping 2017 GP du Canton d'Argovie.gpx, already processed.
# Skipping 2017 GP Industria & Artigianato.gpx, already processed.
# Skipping 2017 GP Stad Zottegem.gpx, already processed.
# Skipping 2017 Gran Premio Beghelli Internazionale Donne Elite.gpx, already processed.
# Skipping 2017 Gran Premio Bruno Beghelli.gpx, already processed.
# Skipping 2017 Gran Premio Citta di Lugano.gpx, already processed.
# Skipping 2017 Gran Premio Costa degli Etruschi.gpx, already processed.
# Skipping 2017 Gran Premio Miguel Indurain.gpx, already processed.
# Skipping 2017 Grand Prix Cerami.gpx, already processed.
# Skipping 2017 Grand Prix Cycliste de Gatineau - ITT.gpx, already processed.
# Skipping 2017 Grand Prix Cycliste de Gatineau.gpx, already processed.
# Skipping 2017 Grand Prix Cycliste de Montreal.gpx, already processed.
# Skipping 2017 Grand Prix Cycliste de Quebec.gpx, already processed.
# Skipping 2017 Grand Prix Cycliste la Marseillaise.gpx, already processed.
# Skipping 2017 Grand Prix d'Isbergues - Pas de Calais.gpx, already processed.
# Skipping 2017 Grand Prix de la Somme .gpx, already processed.
# Skipping 2017 Grand Prix de Plumelec-Morbihan.gpx, already processed.
# Skipping 2017 Grand Prix de Wallonie.gpx, already processed.
# Skipping 2017 Gree-Tour of Guangxi Women s Elite World Challenge.gpx, already processed.
# Skipping 2017 Grote Prijs Jean Pierre Monsere.gpx, already processed.
# Skipping 2017 Grote Prijs Jef Scherens - Rondom Leuven.gpx, already processed.
# Skipping 2017 Halle-Ingooigem.gpx, already processed.
# Skipping 2017 Hammer Series - Hammer Sportzone Limburg Stage 1.gpx, already processed.
# Skipping 2017 Hammer Series - Hammer Sportzone Limburg Stage 2.gpx, already processed.
# Skipping 2017 Hammer Series - Hammer Sportzone Limburg Stage 3.gpx, already processed.
# Skipping 2017 Handzame Classic.gpx, already processed.
# Skipping 2017 Herald Sun Tour Prologue.gpx, already processed.
# Skipping 2017 Herald Sun Tour Stage 1.gpx, already processed.
# Skipping 2017 Herald Sun Tour Stage 2.gpx, already processed.
# Skipping 2017 Herald Sun Tour Stage 3.gpx, already processed.
# Skipping 2017 Herald Sun Tour Stage 4.gpx, already processed.
# Skipping 2017 Il Lombardia.gpx, already processed.
# Skipping 2017 Internationale Thuringen Rundfahrt der Frauen Prologue.gpx, already processed.
# Skipping 2017 Internationale Thuringen Rundfahrt der Frauen Stage 1.gpx, already processed.
# Skipping 2017 Internationale Thuringen Rundfahrt der Frauen Stage 2.gpx, already processed.
# Skipping 2017 Internationale Thuringen Rundfahrt der Frauen Stage 3.gpx, already processed.
# Skipping 2017 Internationale Thuringen Rundfahrt der Frauen Stage 4.gpx, already processed.
# Skipping 2017 Internationale Thuringen Rundfahrt der Frauen Stage 5.gpx, already processed.
# Skipping 2017 Internationale Thuringen Rundfahrt der Frauen Stage 6.gpx, already processed.
# Skipping 2017 Irish Road National Championship - ITT.gpx, already processed.
# Skipping 2017 Irish Road National Championship.gpx, already processed.
# Skipping 2017 Italian Road National Championships - ITT.gpx, already processed.
# Skipping 2017 Italian Road National Championships.gpx, already processed.
# Skipping 2017 Japan Cup Cycle Road Race.gpx, already processed.
# Skipping 2017 Kampioenschap van Vlaanderen.gpx, already processed.
# Skipping 2017 Klasika Primavera de Amorebieta.gpx, already processed.
# Skipping 2017 Kuurne-Bruxelles-Kuurne.gpx, already processed.
# Skipping 2017 La Classique Morbihan.gpx, already processed.
# Skipping 2017 La Course by Le Tour de France.gpx, already processed.
# Skipping 2017 La Fleche Wallonne Femmes.gpx, already processed.
# Skipping 2017 La Fleche Wallonne.gpx, already processed.
# Skipping 2017 La Poly Normande.gpx, already processed.
# Skipping 2017 La Roue Tourangelle Region Centre Val de Loire - Trophee Harmonie Mutuelle.gpx, already processed.
# Skipping 2017 La Tropicale Amissa Bongo Stage 1.gpx, already processed.
# Skipping 2017 La Tropicale Amissa Bongo Stage 2.gpx, already processed.
# Skipping 2017 La Tropicale Amissa Bongo Stage 3.gpx, already processed.
# Skipping 2017 La Tropicale Amissa Bongo Stage 4.gpx, already processed.
# Skipping 2017 La Tropicale Amissa Bongo Stage 5.gpx, already processed.
# Skipping 2017 La Tropicale Amissa Bongo Stage 6.gpx, already processed.
# Skipping 2017 La Tropicale Amissa Bongo Stage 7.gpx, already processed.
# Skipping 2017 Le Samyn des Dames.gpx, already processed.
# Skipping 2017 Le Samyn.gpx, already processed.
# Skipping 2017 Le Tour de France Saitama Criterium.gpx, already processed.
# Skipping 2017 Le Tour de France Shanghai Criterium.gpx, already processed.
# Skipping 2017 Le Tour de Langkawi Stage 1.gpx, already processed.
# Skipping 2017 Le Tour de Langkawi Stage 2.gpx, already processed.
# Skipping 2017 Le Tour de Langkawi Stage 3.gpx, already processed.
# Skipping 2017 Le Tour de Langkawi Stage 4.gpx, already processed.
# Skipping 2017 Le Tour de Langkawi Stage 5.gpx, already processed.
# Skipping 2017 Le Tour de Langkawi Stage 6.gpx, already processed.
# Skipping 2017 Le Tour de Langkawi Stage 7.gpx, already processed.
# Skipping 2017 Le Tour de Langkawi Stage 8.gpx, already processed.
# Skipping 2017 Liege - Bastogne - Liege Femmes.gpx, already processed.
# Skipping 2017 Liege - Bastogne - Liege.gpx, already processed.
# Skipping 2017 Lotto Belgium Tour Prologue.gpx, already processed.
# Skipping 2017 Lotto Belgium Tour Stage 1.gpx, already processed.
# Skipping 2017 Lotto Belgium Tour Stage 2.gpx, already processed.
# Skipping 2017 Lotto Belgium Tour Stage 3.gpx, already processed.
# Skipping 2017 Luxembourg Road National Championships - ITT.gpx, already processed.
# Skipping 2017 Luxembourg Road National Championships.gpx, already processed.
# Skipping 2017 Madrid Challenge by la Vuelta.gpx, already processed.
# Skipping 2017 Memorial Pantani.gpx, already processed.
# Skipping 2017 Milano - Sanremo.gpx, already processed.
# Skipping 2017 Milano - Torino.gpx, already processed.
# Skipping 2017 Netherlands Road National Championships - ITT.gpx, already processed.
# Skipping 2017 Netherlands Road National Championships.gpx, already processed.
# Skipping 2017 New Zealand Road National Championships - ITT.gpx, already processed.
# Skipping 2017 New Zealand Road National Championships.gpx, already processed.
# Skipping 2017 Norvegian Road National Championships.gpx, already processed.
# Skipping 2017 Norwegian Road National Championships - ITT.gpx, already processed.
# Skipping 2017 OCC Oceanian Championships - ITT.gpx, already processed.
# Skipping 2017 OCC Oceanian Championships.gpx, already processed.
# Skipping 2017 Omloop Eurometropool.gpx, already processed.
# Skipping 2017 Omloop Het Nieuwsblad.gpx, already processed.
# Skipping 2017 Omloop Mandel-Leie-Schelde Meulebeke.gpx, already processed.
# Skipping 2017 Omloop van het Houtland Lichtervelde.gpx, already processed.
# Skipping 2017 Osterreich Rundfahrt Prologue.gpx, already processed.
# Skipping 2017 Osterreich Rundfahrt Stage 1.gpx, already processed.
# Skipping 2017 Osterreich Rundfahrt Stage 2.gpx, already processed.
# Skipping 2017 Osterreich Rundfahrt Stage 3.gpx, already processed.
# Skipping 2017 Osterreich Rundfahrt Stage 4.gpx, already processed.
# Skipping 2017 Osterreich Rundfahrt Stage 5.gpx, already processed.
# Skipping 2017 Osterreich Rundfahrt Stage 6.gpx, already processed.
# Skipping 2017 OVO Energy Tour of Britain Stage 1.gpx, already processed.
# Skipping 2017 OVO Energy Tour of Britain Stage 2.gpx, already processed.
# Skipping 2017 OVO Energy Tour of Britain Stage 3.gpx, already processed.
# Skipping 2017 OVO Energy Tour of Britain Stage 4.gpx, already processed.
# Skipping 2017 OVO Energy Tour of Britain Stage 5.gpx, already processed.
# Skipping 2017 OVO Energy Tour of Britain Stage 6.gpx, already processed.
# Skipping 2017 OVO Energy Tour of Britain Stage 7.gpx, already processed.
# Skipping 2017 OVO Energy Tour of Britain Stage 8.gpx, already processed.
# Skipping 2017 Paris - Bourges.gpx, already processed.
# Skipping 2017 Paris - Camembert.gpx, already processed.
# Skipping 2017 Paris - Roubaix.gpx, already processed.
# Skipping 2017 Paris - Tours.gpx, already processed.
# Skipping 2017 Paris-Nice Stage 1.gpx, already processed.
# Skipping 2017 Paris-Nice Stage 2.gpx, already processed.
# Skipping 2017 Paris-Nice Stage 3.gpx, already processed.
# Skipping 2017 Paris-Nice Stage 4.gpx, already processed.
# Skipping 2017 Paris-Nice Stage 5.gpx, already processed.
# Skipping 2017 Paris-Nice Stage 6.gpx, already processed.
# Skipping 2017 Paris-Nice Stage 7.gpx, already processed.
# Skipping 2017 Paris-Nice Stage 8.gpx, already processed.
# Skipping 2017 People's Choice Classic.gpx, already processed.
# Skipping 2017 Polish National Road Championships - ITT.gpx, already processed.
# Skipping 2017 Polish National Road Championships.gpx, already processed.
# Skipping 2017 Portugal National Road Championships - ITT.gpx, already processed.
# Skipping 2017 Portugal Road National Championships.gpx, already processed.
# Skipping 2017 PostNord Danmark Rundt - Tour of Denmark Stage 1.gpx, already processed.
# Skipping 2017 PostNord Danmark Rundt - Tour of Denmark Stage 2.gpx, already processed.
# Skipping 2017 PostNord Danmark Rundt - Tour of Denmark Stage 3.gpx, already processed.
# Skipping 2017 PostNord Danmark Rundt - Tour of Denmark Stage 4.gpx, already processed.
# Skipping 2017 PostNord Danmark Rundt - Tour of Denmark Stage 5.gpx, already processed.
# Skipping 2017 Presidential Cycling Tour of Turkey Stage 1.gpx, already processed.
# Skipping 2017 Presidential Cycling Tour of Turkey Stage 2.gpx, already processed.
# Skipping 2017 Presidential Cycling Tour of Turkey Stage 3.gpx, already processed.
# Skipping 2017 Presidential Cycling Tour of Turkey Stage 4.gpx, already processed.
# Skipping 2017 Presidential Cycling Tour of Turkey Stage 5.gpx, already processed.
# Skipping 2017 Presidential Cycling Tour of Turkey Stage 6.gpx, already processed.
# Skipping 2017 Primus Classic Impanis - Van Petegem.gpx, already processed.
# Skipping 2017 PRO Oetztaler 5500.gpx, already processed.
# Skipping 2017 Prudential RideLondon Classique.gpx, already processed.
# Skipping 2017 Prudential RideLondon-Surrey Classic.gpx, already processed.
# Skipping 2017 Prueba Villafranca-Ordiziako Klasika.gpx, already processed.
# Skipping 2017 Rad am Ring.gpx, already processed.
# Skipping 2017 Record Bank E3 Harelbeke.gpx, already processed.
# Skipping 2017 Ronde de l'Isard Stage 1.gpx, already processed.
# Skipping 2017 Ronde de l'Isard Stage 2.gpx, already processed.
# Skipping 2017 Ronde de l'Isard Stage 3.gpx, already processed.
# Skipping 2017 Ronde de l'Isard Stage 4.gpx, already processed.
# Skipping 2017 Ronde van Drenthe.gpx, already processed.
# Skipping 2017 Ronde van Limburg.gpx, already processed.
# Skipping 2017 Ronde Van Vlaanderen.gpx, already processed.
# Skipping 2017 Route Adelie de Vitre.gpx, already processed.
# Skipping 2017 Route du Sud - La Depeche du Midi Stage 1.gpx, already processed.
# Skipping 2017 Route du Sud - La Depeche du Midi Stage 2.gpx, already processed.
# Skipping 2017 Route du Sud - La Depeche du Midi Stage 3.gpx, already processed.
# Skipping 2017 Route du Sud - La Depeche du Midi Stage 4.gpx, already processed.
# Skipping 2017 Royal Bernard Drome Classic.gpx, already processed.
# Skipping 2017 Rund um Koln.gpx, already processed.
# Skipping 2017 Russian Road National Championships ITT.gpx, already processed.
# Skipping 2017 Russian Road National Championships.gpx, already processed.
# Skipping 2017 Santos Tour Down Under Stage 1.gpx, already processed.
# Skipping 2017 Santos Tour Down Under Stage 2.gpx, already processed.
# Skipping 2017 Santos Tour Down Under Stage 3.gpx, already processed.
# Skipping 2017 Santos Tour Down Under Stage 4.gpx, already processed.
# Skipping 2017 Santos Tour Down Under Stage 5.gpx, already processed.
# Skipping 2017 Santos Tour Down Under Stage 6.gpx, already processed.
# Skipping 2017 Schaal Sels.gpx, already processed.
# Skipping 2017 Scheldeprijs.gpx, already processed.
# Skipping 2017 Sibiu Cycling Tour Prologue.gpx, already processed.
# Skipping 2017 Sibiu Cycling Tour Stage 1.gpx, already processed.
# Skipping 2017 Sibiu Cycling Tour Stage 2.gpx, already processed.
# Skipping 2017 Sibiu Cycling Tour Stage 3.gpx, already processed.
# Skipping 2017 Sibiu Cycling Tour Stage 4.gpx, already processed.
# Skipping 2017 Slovakian Road National Championships - ITT.gpx, already processed.
# Skipping 2017 Slovakian Road National Championships.gpx, already processed.
# Skipping 2017 Sluitingsprijs Putte-Kapellen.gpx, already processed.
# Skipping 2017 South African Road National Championships - ITT.gpx, already processed.
# Skipping 2017 South African Road National Championships.gpx, already processed.
# Skipping 2017 Spanish Road National Championships - ITT.gpx, already processed.
# Skipping 2017 Spanish Road National Championships.gpx, already processed.
# Skipping 2017 SPAR Flanders Diamond Tour.gpx, already processed.
# Skipping 2017 Spar omloop van Het Hageland.gpx, already processed.
# Skipping 2017 Sparkassen Muensterland Giro.gpx, already processed.
# Skipping 2017 Ster ZLM Toer GP Jan van Heeswijk Prologue.gpx, already processed.
# Skipping 2017 Ster ZLM Toer GP Jan van Heeswijk Stage 1.gpx, already processed.
# Skipping 2017 Ster ZLM Toer GP Jan van Heeswijk Stage 2.gpx, already processed.
# Skipping 2017 Ster ZLM Toer GP Jan van Heeswijk Stage 3.gpx, already processed.
# Skipping 2017 Ster ZLM Toer GP Jan van Heeswijk Stage 4.gpx, already processed.
# Skipping 2017 Strade Bianche.gpx, already processed.
# Skipping 2017 Swedish Road National Championships - ITT.gpx, already processed.
# Skipping 2017 Swedish Road National Championships.gpx, already processed.
# Skipping 2017 Swiss Road National Championships - ITT.gpx, already processed.
# Skipping 2017 Swiss Road National Championships.gpx, already processed.
# Skipping 2017 Szlakiem Walk Majora Hubala Stage 1.gpx, already processed.
# Skipping 2017 Szlakiem Walk Majora Hubala Stage 2-1.gpx, already processed.
# Skipping 2017 Szlakiem Walk Majora Hubala Stage 2-2.gpx, already processed.
# Skipping 2017 Szlakiem Walk Majora Hubala Stage 3.gpx, already processed.
# Skipping 2017 Szlakiem Walk Majora Hubala Stage 4.gpx, already processed.
# Skipping 2017 Tacx Pro Classic.gpx, already processed.
# Skipping 2017 Telkom 947 Cycle Challenge.gpx, already processed.
# Skipping 2017 The Larry H.Miller Tour of Utah Stage 1.gpx, already processed.
# Skipping 2017 The Larry H.Miller Tour of Utah Stage 2.gpx, already processed.
# Skipping 2017 The Larry H.Miller Tour of Utah Stage 3.gpx, already processed.
# Skipping 2017 The Larry H.Miller Tour of Utah Stage 4.gpx, already processed.
# Skipping 2017 The Larry H.Miller Tour of Utah Stage 5.gpx, already processed.
# Skipping 2017 The Larry H.Miller Tour of Utah Stage 6.gpx, already processed.
# Skipping 2017 The Larry H.Miller Tour of Utah Stage 7.gpx, already processed.
# Skipping 2017 Tirreno-Adriatico Stage 1.gpx, already processed.
# Skipping 2017 Tirreno-Adriatico Stage 2.gpx, already processed.
# Skipping 2017 Tirreno-Adriatico Stage 3.gpx, already processed.
# Skipping 2017 Tirreno-Adriatico Stage 4.gpx, already processed.
# Skipping 2017 Tirreno-Adriatico Stage 5.gpx, already processed.
# Skipping 2017 Tirreno-Adriatico Stage 6.gpx, already processed.
# Skipping 2017 Tirreno-Adriatico Stage 7.gpx, already processed.
# Skipping 2017 Tour Cycliste International du Haut Var-matin Stage 1.gpx, already processed.
# Skipping 2017 Tour Cycliste International du Haut Var-matin Stage 2.gpx, already processed.
# Skipping 2017 Tour Cycliste International La Provence Stage 1.gpx, already processed.
# Skipping 2017 Tour Cycliste International La Provence Stage 2.gpx, already processed.
# Skipping 2017 Tour Cycliste International La Provence Stage 3.gpx, already processed.
# Skipping 2017 Tour d'Azerbaidjan Stage 1.gpx, already processed.
# Skipping 2017 Tour d'Azerbaidjan Stage 2.gpx, already processed.
# Skipping 2017 Tour d'Azerbaidjan Stage 3.gpx, already processed.
# Skipping 2017 Tour d'Azerbaidjan Stage 4.gpx, already processed.
# Skipping 2017 Tour d'Azerbaidjan Stage 5.gpx, already processed.
# Skipping 2017 Tour de France Stage 1.gpx, already processed.
# Skipping 2017 Tour de France Stage 10.gpx, already processed.
# Skipping 2017 Tour de France Stage 11.gpx, already processed.
# Skipping 2017 Tour de France Stage 12.gpx, already processed.
# Skipping 2017 Tour de France Stage 13.gpx, already processed.
# Skipping 2017 Tour de France Stage 14.gpx, already processed.
# Skipping 2017 Tour de France Stage 15.gpx, already processed.
# Skipping 2017 Tour de France Stage 16.gpx, already processed.
# Skipping 2017 Tour de France Stage 17.gpx, already processed.
# Skipping 2017 Tour de France Stage 18.gpx, already processed.
# Skipping 2017 Tour de France Stage 19.gpx, already processed.
# Skipping 2017 Tour de France Stage 2.gpx, already processed.
# Skipping 2017 Tour de France Stage 20.gpx, already processed.
# Skipping 2017 Tour de France Stage 21.gpx, already processed.
# Skipping 2017 Tour de France Stage 3.gpx, already processed.
# Skipping 2017 Tour de France Stage 4.gpx, already processed.
# Skipping 2017 Tour de France Stage 5.gpx, already processed.
# Skipping 2017 Tour de France Stage 6.gpx, already processed.
# Skipping 2017 Tour de France Stage 7.gpx, already processed.
# Skipping 2017 Tour de France Stage 8.gpx, already processed.
# Skipping 2017 Tour de France Stage 9.gpx, already processed.
# Skipping 2017 Tour de l'Ain Prologue.gpx, already processed.
# Skipping 2017 Tour de l'Ain Stage 1.gpx, already processed.
# Skipping 2017 Tour de l'Ain Stage 2.gpx, already processed.
# Skipping 2017 Tour de l'Ain Stage 3.gpx, already processed.
# Skipping 2017 Tour de l'Ain Stage 4.gpx, already processed.
# Skipping 2017 Tour de l'Avenir Stage 1.gpx, already processed.
# Skipping 2017 Tour de l'Avenir Stage 2.gpx, already processed.
# Skipping 2017 Tour de l'Avenir Stage 3.gpx, already processed.
# Skipping 2017 Tour de l'Avenir Stage 4.gpx, already processed.
# Skipping 2017 Tour de l'Avenir Stage 5.gpx, already processed.
# Skipping 2017 Tour de l'Avenir Stage 6.gpx, already processed.
# Skipping 2017 Tour de l'Avenir Stage 7.gpx, already processed.
# Skipping 2017 Tour de l'Avenir Stage 8.gpx, already processed.
# Skipping 2017 Tour de l'Avenir Stage 9.gpx, already processed.
# Skipping 2017 Tour de l'Eurometropole.gpx, already processed.
# Skipping 2017 Tour de Luxembourg Prologue.gpx, already processed.
# Skipping 2017 Tour de Luxembourg Stage 1.gpx, already processed.
# Skipping 2017 Tour de Luxembourg Stage 2.gpx, already processed.
# Skipping 2017 Tour de Luxembourg Stage 3.gpx, already processed.
# Skipping 2017 Tour de Luxembourg Stage 4.gpx, already processed.
# Skipping 2017 Tour de Normandie Stage 1.gpx, already processed.
# Skipping 2017 Tour de Normandie Stage 2.gpx, already processed.
# Skipping 2017 Tour de Normandie Stage 3.gpx, already processed.
# Skipping 2017 Tour de Normandie Stage 4.gpx, already processed.
# Skipping 2017 Tour de Normandie Stage 5.gpx, already processed.
# Skipping 2017 Tour de Normandie Stage 6.gpx, already processed.
# Skipping 2017 Tour de Normandie Stage 7.gpx, already processed.
# Skipping 2017 Tour de Pologne Stage 1.gpx, already processed.
# Skipping 2017 Tour de Pologne Stage 2.gpx, already processed.
# Skipping 2017 Tour de Pologne Stage 3.gpx, already processed.
# Skipping 2017 Tour de Pologne Stage 4.gpx, already processed.
# Skipping 2017 Tour de Pologne Stage 5.gpx, already processed.
# Skipping 2017 Tour de Pologne Stage 6.gpx, already processed.
# Skipping 2017 Tour de Pologne Stage 7.gpx, already processed.
# Skipping 2017 Tour de Romandie Prologue.gpx, already processed.
# Skipping 2017 Tour de Romandie Stage 1.gpx, already processed.
# Skipping 2017 Tour de Romandie Stage 2.gpx, already processed.
# Skipping 2017 Tour de Romandie Stage 3.gpx, already processed.
# Skipping 2017 Tour de Romandie Stage 4.gpx, already processed.
# Skipping 2017 Tour de Romandie Stage 5.gpx, already processed.
# Skipping 2017 Tour de Suisse Prologue.gpx, already processed.
# Skipping 2017 Tour de Suisse Stage 1.gpx, already processed.
# Skipping 2017 Tour de Suisse Stage 2.gpx, already processed.
# Skipping 2017 Tour de Suisse Stage 3.gpx, already processed.
# Skipping 2017 Tour de Suisse Stage 4.gpx, already processed.
# Skipping 2017 Tour de Suisse Stage 5.gpx, already processed.
# Skipping 2017 Tour de Suisse Stage 6.gpx, already processed.
# Skipping 2017 Tour de Suisse Stage 7.gpx, already processed.
# Skipping 2017 Tour de Suisse Stage 8.gpx, already processed.
# Skipping 2017 Tour de Taiwan Stage 1.gpx, already processed.
# Skipping 2017 Tour de Taiwan Stage 2.gpx, already processed.
# Skipping 2017 Tour de Taiwan Stage 3.gpx, already processed.
# Skipping 2017 Tour de Taiwan Stage 4.gpx, already processed.
# Skipping 2017 Tour de Taiwan Stage 5.gpx, already processed.
# Skipping 2017 Tour de Vendee.gpx, already processed.
# Skipping 2017 Tour de Yorkshire Stage 1.gpx, already processed.
# Skipping 2017 Tour de Yorkshire Stage 2.gpx, already processed.
# Skipping 2017 Tour de Yorkshire Stage 3.gpx, already processed.
# Skipping 2017 Tour de Yorkshire Women's Race.gpx, already processed.
# Skipping 2017 Tour des Fjords Stage 1.gpx, already processed.
# Skipping 2017 Tour des Fjords Stage 2.gpx, already processed.
# Skipping 2017 Tour des Fjords Stage 3.gpx, already processed.
# Skipping 2017 Tour des Fjords Stage 4.gpx, already processed.
# Skipping 2017 Tour des Fjords Stage 5.gpx, already processed.
# Skipping 2017 Tour du Doubs.gpx, already processed.
# Skipping 2017 Tour du Finistere.gpx, already processed.
# Skipping 2017 Tour du Limousin Stage 1.gpx, already processed.
# Skipping 2017 Tour du Limousin Stage 2.gpx, already processed.
# Skipping 2017 Tour du Limousin Stage 3.gpx, already processed.
# Skipping 2017 Tour du Limousin Stage 4.gpx, already processed.
# Skipping 2017 Tour of Alberta Stage 1.gpx, already processed.
# Skipping 2017 Tour of Alberta Stage 2.gpx, already processed.
# Skipping 2017 Tour of Alberta Stage 3.gpx, already processed.
# Skipping 2017 Tour of Alberta Stage 4.gpx, already processed.
# Skipping 2017 Tour of Almaty Stage 1.gpx, already processed.
# Skipping 2017 Tour of Almaty Stage 2.gpx, already processed.
# Skipping 2017 Tour of California Stage 1.gpx, already processed.
# Skipping 2017 Tour of California Stage 2.gpx, already processed.
# Skipping 2017 Tour of California Stage 3.gpx, already processed.
# Skipping 2017 Tour of California Stage 4.gpx, already processed.
# Skipping 2017 Tour of Chongming Island Stage 1.gpx, already processed.
# Skipping 2017 Tour of Chongming Island Stage 2.gpx, already processed.
# Skipping 2017 Tour of Chongming Island Stage 3.gpx, already processed.
# Skipping 2017 Tour of Croatia Stage 1.gpx, already processed.
# Skipping 2017 Tour of Croatia Stage 2.gpx, already processed.
# Skipping 2017 Tour of Croatia Stage 3.gpx, already processed.
# Skipping 2017 Tour of Croatia Stage 4.gpx, already processed.
# Skipping 2017 Tour of Croatia Stage 5.gpx, already processed.
# Skipping 2017 Tour of Croatia Stage 6.gpx, already processed.
# Skipping 2017 Tour of Estonia Stage 1.gpx, already processed.
# Skipping 2017 Tour of Estonia Stage 2.gpx, already processed.
# Skipping 2017 Tour of Fuzhou Stage 1.gpx, already processed.
# Skipping 2017 Tour of Fuzhou Stage 2.gpx, already processed.
# Skipping 2017 Tour of Fuzhou Stage 3.gpx, already processed.
# Skipping 2017 Tour of Fuzhou Stage 4.gpx, already processed.
# Skipping 2017 Tour of Fuzhou Stage 5.gpx, already processed.
# Skipping 2017 Tour of Guangxi Stage 1.gpx, already processed.
# Skipping 2017 Tour of Guangxi Stage 2.gpx, already processed.
# Skipping 2017 Tour of Guangxi Stage 3.gpx, already processed.
# Skipping 2017 Tour of Guangxi Stage 4.gpx, already processed.
# Skipping 2017 Tour of Guangxi Stage 5.gpx, already processed.
# Skipping 2017 Tour of Guangxi Stage 6.gpx, already processed.
# Skipping 2017 Tour of Hainan Stage 1.gpx, already processed.
# Skipping 2017 Tour of Hainan Stage 2.gpx, already processed.
# Skipping 2017 Tour of Hainan Stage 3.gpx, already processed.
# Skipping 2017 Tour of Hainan Stage 4.gpx, already processed.
# Skipping 2017 Tour of Hainan Stage 5.gpx, already processed.
# Skipping 2017 Tour of Hainan Stage 6.gpx, already processed.
# Skipping 2017 Tour of Hainan Stage 7.gpx, already processed.
# Skipping 2017 Tour of Hainan Stage 8.gpx, already processed.
# Skipping 2017 Tour of Hainan Stage 9.gpx, already processed.
# Skipping 2017 Tour of Japan Prologue.gpx, already processed.
# Skipping 2017 Tour of Japan Stage 1.gpx, already processed.
# Skipping 2017 Tour of Japan Stage 2.gpx, already processed.
# Skipping 2017 Tour of Japan Stage 3.gpx, already processed.
# Skipping 2017 Tour of Japan Stage 4.gpx, already processed.
# Skipping 2017 Tour of Japan Stage 5.gpx, already processed.
# Skipping 2017 Tour of Japan Stage 6.gpx, already processed.
# Skipping 2017 Tour of Japan Stage 7.gpx, already processed.
# Skipping 2017 Tour of Norway Stage 1.gpx, already processed.
# Skipping 2017 Tour of Norway Stage 2.gpx, already processed.
# Skipping 2017 Tour of Norway Stage 3.gpx, already processed.
# Skipping 2017 Tour of Norway Stage 4.gpx, already processed.
# Skipping 2017 Tour of Norway Stage 5.gpx, already processed.
# Skipping 2017 Tour of Oman Stage 1.gpx, already processed.
# Skipping 2017 Tour of Oman Stage 2.gpx, already processed.
# Skipping 2017 Tour of Oman Stage 3.gpx, already processed.
# Skipping 2017 Tour of Oman Stage 4.gpx, already processed.
# Skipping 2017 Tour of Oman Stage 5.gpx, already processed.
# Skipping 2017 Tour of Oman Stage 6.gpx, already processed.
# Skipping 2017 Tour of Qinghai Lake Stage 1.gpx, already processed.
# Skipping 2017 Tour of Qinghai Lake Stage 10.gpx, already processed.
# Skipping 2017 Tour of Qinghai Lake Stage 11.gpx, already processed.
# Skipping 2017 Tour of Qinghai Lake Stage 12.gpx, already processed.
# Skipping 2017 Tour of Qinghai Lake Stage 13.gpx, already processed.
# Skipping 2017 Tour of Qinghai Lake Stage 2.gpx, already processed.
# Skipping 2017 Tour of Qinghai Lake Stage 3.gpx, already processed.
# Skipping 2017 Tour of Qinghai Lake Stage 4.gpx, already processed.
# Skipping 2017 Tour of Qinghai Lake Stage 5.gpx, already processed.
# Skipping 2017 Tour of Qinghai Lake Stage 6.gpx, already processed.
# Skipping 2017 Tour of Qinghai Lake Stage 7.gpx, already processed.
# Skipping 2017 Tour of Qinghai Lake Stage 8.gpx, already processed.
# Skipping 2017 Tour of Qinghai Lake Stage 9.gpx, already processed.
# Skipping 2017 Tour of Slovaquie Prologue.gpx, already processed.
# Skipping 2017 Tour of Slovaquie Stage 1.gpx, already processed.
# Skipping 2017 Tour of Slovaquie Stage 2.gpx, already processed.
# Skipping 2017 Tour of Slovaquie Stage 3.gpx, already processed.
# Skipping 2017 Tour of Slovaquie Stage 4.gpx, already processed.
# Skipping 2017 Tour of Slovenia Stage 1.gpx, already processed.
# Skipping 2017 Tour of Slovenia Stage 2.gpx, already processed.
# Skipping 2017 Tour of Slovenia Stage 3.gpx, already processed.
# Skipping 2017 Tour of Slovenia Stage 4.gpx, already processed.
# Skipping 2017 Tour of Thailand Stage 1.gpx, already processed.
# Skipping 2017 Tour of Thailand Stage 2.gpx, already processed.
# Skipping 2017 Tour of Thailand Stage 3.gpx, already processed.
# Skipping 2017 Tour of Thailand Stage 4.gpx, already processed.
# Skipping 2017 Tour of Thailand Stage 5.gpx, already processed.
# Skipping 2017 Tour of Thailand Stage 6.gpx, already processed.
# Skipping 2017 Tour of the Alps Stage 1.gpx, already processed.
# Skipping 2017 Tour of the Alps Stage 2.gpx, already processed.
# Skipping 2017 Tour of the Alps Stage 3.gpx, already processed.
# Skipping 2017 Tour of the Alps Stage 4.gpx, already processed.
# Skipping 2017 Tour of the Alps Stage 5.gpx, already processed.
# Skipping 2017 Tour Poitou-Charentes Stage 1.gpx, already processed.
# Skipping 2017 Tour Poitou-Charentes Stage 2.gpx, already processed.
# Skipping 2017 Tour Poitou-Charentes Stage 3-1.gpx, already processed.
# Skipping 2017 Tour Poitou-Charentes Stage 3-2.gpx, already processed.
# Skipping 2017 Tour Poitou-Charentes Stage 4.gpx, already processed.
# Skipping 2017 Tre Valli Varesine.gpx, already processed.
# Skipping 2017 Tro Bro Leon.gpx, already processed.
# Skipping 2017 Trofee Maarten Wynants.gpx, already processed.
# Skipping 2017 Trofeo Alfredo Binda - Comune di Cittiglio.gpx, already processed.
# Skipping 2017 Trofeo Andratx-Mirador des Colomer.gpx, already processed.
# Skipping 2017 Trofeo Laigueglia.gpx, already processed.
# Skipping 2017 Trofeo Matteotti.gpx, already processed.
# Skipping 2017 Trofeo Palma.gpx, already processed.
# Skipping 2017 Trofeo Porreres-Felanitx-Ses Salines-Campos.gpx, already processed.
# Skipping 2017 Trofeo Serra de Tramuntana.gpx, already processed.
# Skipping 2017 UCI Road World Championships - ITT.gpx, already processed.
# Skipping 2017 UCI Road World Championships - TTT.gpx, already processed.
# Skipping 2017 UCI Road World Championships.gpx, already processed.
# Skipping 2017 UEC European Championships - ITT.gpx, already processed.
# Skipping 2017 UEC European Championships.gpx, already processed.
# Skipping 2017 USA Road National Championships - ITT.gpx, already processed.
# Skipping 2017 USA Road National Championships.gpx, already processed.
# Skipping 2017 Velothon Wales.gpx, already processed.
# Skipping 2017 Volta a la Comunitat Valenciana Stage 1.gpx, already processed.
# Skipping 2017 Volta a la Comunitat Valenciana Stage 2.gpx, already processed.
# Skipping 2017 Volta a la Comunitat Valenciana Stage 3.gpx, already processed.
# Skipping 2017 Volta a la Comunitat Valenciana Stage 4.gpx, already processed.
# Skipping 2017 Volta a la Comunitat Valenciana Stage 5.gpx, already processed.
# Skipping 2017 Volta a Portugal em Bicicleta Santander Totta Prologue.gpx, already processed.
# Skipping 2017 Volta a Portugal em Bicicleta Santander Totta Stage 1.gpx, already processed.
# Skipping 2017 Volta a Portugal em Bicicleta Santander Totta Stage 10.gpx, already processed.
# Skipping 2017 Volta a Portugal em Bicicleta Santander Totta Stage 2.gpx, already processed.
# Skipping 2017 Volta a Portugal em Bicicleta Santander Totta Stage 3.gpx, already processed.
# Skipping 2017 Volta a Portugal em Bicicleta Santander Totta Stage 4.gpx, already processed.
# Skipping 2017 Volta a Portugal em Bicicleta Santander Totta Stage 5.gpx, already processed.
# Skipping 2017 Volta a Portugal em Bicicleta Santander Totta Stage 6.gpx, already processed.
# Skipping 2017 Volta a Portugal em Bicicleta Santander Totta Stage 7.gpx, already processed.
# Skipping 2017 Volta a Portugal em Bicicleta Santander Totta Stage 8.gpx, already processed.
# Skipping 2017 Volta a Portugal em Bicicleta Santander Totta Stage 9.gpx, already processed.
# Skipping 2017 Volta ao Alentejo Stage 1.gpx, already processed.
# Skipping 2017 Volta ao Alentejo Stage 2.gpx, already processed.
# Skipping 2017 Volta ao Alentejo Stage 3.gpx, already processed.
# Skipping 2017 Volta ao Alentejo Stage 4.gpx, already processed.
# Skipping 2017 Volta ao Alentejo Stage 5.gpx, already processed.
# Skipping 2017 Volta ao Algarve em Bicicleta Stage 1.gpx, already processed.
# Skipping 2017 Volta ao Algarve em Bicicleta Stage 2.gpx, already processed.
# Skipping 2017 Volta ao Algarve em Bicicleta Stage 3.gpx, already processed.
# Skipping 2017 Volta ao Algarve em Bicicleta Stage 4.gpx, already processed.
# Skipping 2017 Volta ao Algarve em Bicicleta Stage 5.gpx, already processed.
# Skipping 2017 Volta Ciclista a Catalunya Stage 1.gpx, already processed.
# Skipping 2017 Volta Ciclista a Catalunya Stage 2.gpx, already processed.
# Skipping 2017 Volta Ciclista a Catalunya Stage 3.gpx, already processed.
# Skipping 2017 Volta Ciclista a Catalunya Stage 4.gpx, already processed.
# Skipping 2017 Volta Ciclista a Catalunya Stage 5.gpx, already processed.
# Skipping 2017 Volta Ciclista a Catalunya Stage 6.gpx, already processed.
# Skipping 2017 Volta Ciclista a Catalunya Stage 7.gpx, already processed.
# Skipping 2017 Volta Limburg Classic.gpx, already processed.
# Skipping 2017 VOO-Tour de Wallonie Stage 1.gpx, already processed.
# Skipping 2017 VOO-Tour de Wallonie Stage 2.gpx, already processed.
# Skipping 2017 VOO-Tour de Wallonie Stage 3.gpx, already processed.
# Skipping 2017 VOO-Tour de Wallonie Stage 4.gpx, already processed.
# Skipping 2017 VOO-Tour de Wallonie Stage 5.gpx, already processed.
# Skipping 2017 Vuelta a Andalucia Ruta Ciclista Del Sol Stage 1.gpx, already processed.
# Skipping 2017 Vuelta a Andalucia Ruta Ciclista Del Sol Stage 2.gpx, already processed.
# Skipping 2017 Vuelta a Andalucia Ruta Ciclista Del Sol Stage 3.gpx, already processed.
# Skipping 2017 Vuelta a Andalucia Ruta Ciclista Del Sol Stage 4.gpx, already processed.
# Skipping 2017 Vuelta a Andalucia Ruta Ciclista Del Sol Stage 5.gpx, already processed.
# Skipping 2017 Vuelta a Asturias Stage 1.gpx, already processed.
# Skipping 2017 Vuelta a Asturias Stage 2.gpx, already processed.
# Skipping 2017 Vuelta a Asturias Stage 3.gpx, already processed.
# Skipping 2017 Vuelta a Burgos Stage 1.gpx, already processed.
# Skipping 2017 Vuelta a Burgos Stage 2.gpx, already processed.
# Skipping 2017 Vuelta a Burgos Stage 3.gpx, already processed.
# Skipping 2017 Vuelta a Burgos Stage 4.gpx, already processed.
# Skipping 2017 Vuelta a Burgos Stage 5.gpx, already processed.
# Skipping 2017 Vuelta a Castilla y Leon Stage 1.gpx, already processed.
# Skipping 2017 Vuelta a Castilla y Leon Stage 2.gpx, already processed.
# Skipping 2017 Vuelta a Castilla y Leon Stage 3.gpx, already processed.
# Skipping 2017 Vuelta a Espana Stage 1.gpx, already processed.
# Skipping 2017 Vuelta a Espana Stage 10.gpx, already processed.
# Skipping 2017 Vuelta a Espana Stage 11.gpx, already processed.
# Skipping 2017 Vuelta a Espana Stage 12.gpx, already processed.
# Skipping 2017 Vuelta a Espana Stage 13.gpx, already processed.
# Skipping 2017 Vuelta a Espana Stage 14.gpx, already processed.
# Skipping 2017 Vuelta a Espana Stage 15.gpx, already processed.
# Skipping 2017 Vuelta a Espana Stage 16.gpx, already processed.
# Skipping 2017 Vuelta a Espana Stage 17.gpx, already processed.
# Skipping 2017 Vuelta a Espana Stage 18.gpx, already processed.
# Skipping 2017 Vuelta a Espana Stage 19.gpx, already processed.
# Skipping 2017 Vuelta a Espana Stage 2.gpx, already processed.
# Skipping 2017 Vuelta a Espana Stage 20.gpx, already processed.
# Skipping 2017 Vuelta a Espana Stage 21.gpx, already processed.
# Skipping 2017 Vuelta a Espana Stage 3.gpx, already processed.
# Skipping 2017 Vuelta a Espana Stage 4.gpx, already processed.
# ...
# Processing 2023 Volta Ciclista a Catalunya Stage 4.gpx...
# Saved to data/gpx_parsed\2023 Volta Ciclista a Catalunya Stage 4.csv
# Processing 2023 Volta Ciclista a Catalunya Stage 5.gpx...
# Saved to data/gpx_parsed\2023 Volta Ciclista a Catalunya Stage 5.csv
# Processing 2023 Volta Ciclista a Catalunya Stage 6.gpx...
# Saved to data/gpx_parsed\2023 Volta Ciclista a Catalunya Stage 6.csv
# Processing 2023 Volta Ciclista a Catalunya Stage 7.gpx...
# Saved to data/gpx_parsed\2023 Volta Ciclista a Catalunya Stage 7.csv
# Processing 2023 Volta Limburg Classic.gpx...
# Saved to data/gpx_parsed\2023 Volta Limburg Classic.csv
# Processing 2023 Vuelta a Andalucia Ruta Ciclista Del Sol Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Andalucia Ruta Ciclista Del Sol Stage 1.csv
# Processing 2023 Vuelta a Andalucia Ruta Ciclista Del Sol Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Andalucia Ruta Ciclista Del Sol Stage 2.csv
# Processing 2023 Vuelta a Andalucia Ruta Ciclista Del Sol Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Andalucia Ruta Ciclista Del Sol Stage 3.csv
# Processing 2023 Vuelta a Andalucia Ruta Ciclista Del Sol Stage 4.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Andalucia Ruta Ciclista Del Sol Stage 4.csv
# Processing 2023 Vuelta a Andalucia Ruta Ciclista Del Sol Stage 5.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Andalucia Ruta Ciclista Del Sol Stage 5.csv
# Processing 2023 Vuelta a Burgos Feminas Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Burgos Feminas Stage 1.csv
# Processing 2023 Vuelta a Burgos Feminas Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Burgos Feminas Stage 2.csv
# Processing 2023 Vuelta a Burgos Feminas Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Burgos Feminas Stage 3.csv
# Processing 2023 Vuelta a Burgos Feminas Stage 4.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Burgos Feminas Stage 4.csv
# Processing 2023 Vuelta a Burgos Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Burgos Stage 1.csv
# Processing 2023 Vuelta a Burgos Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Burgos Stage 2.csv
# Processing 2023 Vuelta a Burgos Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Burgos Stage 3.csv
# Processing 2023 Vuelta a Burgos Stage 4.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Burgos Stage 4.csv
# Processing 2023 Vuelta a Burgos Stage 5.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Burgos Stage 5.csv
# Processing 2023 Vuelta a Castilla y Leon Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Castilla y Leon Stage 1.csv
# Processing 2023 Vuelta a Castilla y Leon Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Castilla y Leon Stage 2.csv
# Processing 2023 Vuelta a Colombia Femenina Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Colombia Femenina Stage 1.csv
# Processing 2023 Vuelta a Colombia Femenina Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Colombia Femenina Stage 2.csv
# Processing 2023 Vuelta a Colombia Femenina Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Colombia Femenina Stage 3.csv
# Processing 2023 Vuelta a Colombia Femenina Stage 4.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Colombia Femenina Stage 4.csv
# Processing 2023 Vuelta a Colombia Femenina Stage 5.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Colombia Femenina Stage 5.csv
# Processing 2023 Vuelta a Colombia Prologue.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Colombia Prologue.csv
# Processing 2023 Vuelta a Colombia Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Colombia Stage 1.csv
# Processing 2023 Vuelta a Colombia Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Colombia Stage 2.csv
# Processing 2023 Vuelta a Colombia Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Colombia Stage 3.csv
# Processing 2023 Vuelta a Colombia Stage 4.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Colombia Stage 4.csv
# Processing 2023 Vuelta a Colombia Stage 5.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Colombia Stage 5.csv
# Processing 2023 Vuelta a Colombia Stage 6.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Colombia Stage 6.csv
# Processing 2023 Vuelta a Colombia Stage 7.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Colombia Stage 7.csv
# Processing 2023 Vuelta a Colombia Stage 8.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Colombia Stage 8.csv
# Processing 2023 Vuelta a Colombia Stage 9.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Colombia Stage 9.csv
# Processing 2023 Vuelta a Formosa Internacional Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Formosa Internacional Stage 1.csv
# Processing 2023 Vuelta a Formosa Internacional Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Formosa Internacional Stage 2.csv
# Processing 2023 Vuelta a Formosa Internacional Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Formosa Internacional Stage 3.csv
# Processing 2023 Vuelta a Formosa Internacional Stage 4-1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Formosa Internacional Stage 4-1.csv
# Processing 2023 Vuelta a Formosa Internacional Stage 4-2.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a Formosa Internacional Stage 4-2.csv
# Processing 2023 Vuelta a San Juan Internacional Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a San Juan Internacional Stage 1.csv
# Processing 2023 Vuelta a San Juan Internacional Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a San Juan Internacional Stage 2.csv
# Processing 2023 Vuelta a San Juan Internacional Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a San Juan Internacional Stage 3.csv
# Processing 2023 Vuelta a San Juan Internacional Stage 4.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a San Juan Internacional Stage 4.csv
# Processing 2023 Vuelta a San Juan Internacional Stage 5.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a San Juan Internacional Stage 5.csv
# Processing 2023 Vuelta a San Juan Internacional Stage 6.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a San Juan Internacional Stage 6.csv
# Processing 2023 Vuelta a San Juan Internacional Stage 7.gpx...
# Saved to data/gpx_parsed\2023 Vuelta a San Juan Internacional Stage 7.csv
# Processing 2023 Vuelta al Tachira en Bicicleta Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta al Tachira en Bicicleta Stage 1.csv
# Processing 2023 Vuelta al Tachira en Bicicleta Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Vuelta al Tachira en Bicicleta Stage 2.csv
# Processing 2023 Vuelta al Tachira en Bicicleta Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Vuelta al Tachira en Bicicleta Stage 3.csv
# Processing 2023 Vuelta al Tachira en Bicicleta Stage 4.gpx...
# Saved to data/gpx_parsed\2023 Vuelta al Tachira en Bicicleta Stage 4.csv
# Processing 2023 Vuelta al Tachira en Bicicleta Stage 5.gpx...
# Saved to data/gpx_parsed\2023 Vuelta al Tachira en Bicicleta Stage 5.csv
# Processing 2023 Vuelta al Tachira en Bicicleta Stage 6.gpx...
# Saved to data/gpx_parsed\2023 Vuelta al Tachira en Bicicleta Stage 6.csv
# Processing 2023 Vuelta al Tachira en Bicicleta Stage 7.gpx...
# Saved to data/gpx_parsed\2023 Vuelta al Tachira en Bicicleta Stage 7.csv
# Processing 2023 Vuelta al Tachira en Bicicleta Stage 8.gpx...
# Saved to data/gpx_parsed\2023 Vuelta al Tachira en Bicicleta Stage 8.csv
# Processing 2023 Vuelta Asturias Julio Alvarez Mendo Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Asturias Julio Alvarez Mendo Stage 1.csv
# Processing 2023 Vuelta Asturias Julio Alvarez Mendo Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Asturias Julio Alvarez Mendo Stage 2.csv
# Processing 2023 Vuelta Asturias Julio Alvarez Mendo Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Asturias Julio Alvarez Mendo Stage 3.csv
# Processing 2023 Vuelta Bantrab Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Bantrab Stage 1.csv
# Processing 2023 Vuelta Bantrab Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Bantrab Stage 2.csv
# Processing 2023 Vuelta Bantrab Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Bantrab Stage 3.csv
# Processing 2023 Vuelta Bantrab Stage 4.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Bantrab Stage 4.csv
# Processing 2023 Vuelta Bantrab Stage 5.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Bantrab Stage 5.csv
# Processing 2023 Vuelta Ciclista a la Region de Murcia Costa Calida.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Ciclista a la Region de Murcia Costa Calida.csv
# Processing 2023 Vuelta Ciclista Andalucia Ruta Del Sol Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Ciclista Andalucia Ruta Del Sol Stage 1.csv
# Processing 2023 Vuelta Ciclista Andalucia Ruta Del Sol Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Ciclista Andalucia Ruta Del Sol Stage 2.csv
# Processing 2023 Vuelta Ciclista Andalucia Ruta Del Sol Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Ciclista Andalucia Ruta Del Sol Stage 3.csv
# Processing 2023 Vuelta Ciclista Andalucia Ruta Del Sol Stage 4.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Ciclista Andalucia Ruta Del Sol Stage 4.csv
# Processing 2023 Vuelta Ciclista Andalucia Ruta Del Sol Stage 5.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Ciclista Andalucia Ruta Del Sol Stage 5.csv
# Processing 2023 Vuelta Ciclistica al Ecuador Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Ciclistica al Ecuador Stage 1.csv
# Processing 2023 Vuelta Ciclistica al Ecuador Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Ciclistica al Ecuador Stage 2.csv
# Processing 2023 Vuelta Ciclistica al Ecuador Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Ciclistica al Ecuador Stage 3.csv
# Processing 2023 Vuelta Ciclistica al Ecuador Stage 4.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Ciclistica al Ecuador Stage 4.csv
# Processing 2023 Vuelta Ciclistica al Ecuador Stage 5.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Ciclistica al Ecuador Stage 5.csv
# Processing 2023 Vuelta Ciclistica al Ecuador Stage 6.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Ciclistica al Ecuador Stage 6.csv
# Processing 2023 Vuelta Ciclistica Internacional Femenina a Guatemala Prologue.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Ciclistica Internacional Femenina a Guatemala Prologue.csv
# Processing 2023 Vuelta Ciclistica Internacional Femenina a Guatemala Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Ciclistica Internacional Femenina a Guatemala Stage 1.csv
# Processing 2023 Vuelta Ciclistica Internacional Femenina a Guatemala Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Ciclistica Internacional Femenina a Guatemala Stage 2.csv
# Processing 2023 Vuelta Ciclistica Internacional Femenina a Guatemala Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Ciclistica Internacional Femenina a Guatemala Stage 3.csv
# Processing 2023 Vuelta Ciclistica Internacional Femenina a Guatemala Stage 4.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Ciclistica Internacional Femenina a Guatemala Stage 4.csv
# Processing 2023 Vuelta CV Feminas.gpx...
# Saved to data/gpx_parsed\2023 Vuelta CV Feminas.csv
# Processing 2023 Vuelta del Porvenir San Luis Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta del Porvenir San Luis Stage 1.csv
# Processing 2023 Vuelta del Porvenir San Luis Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Vuelta del Porvenir San Luis Stage 2.csv
# Processing 2023 Vuelta del Porvenir San Luis Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Vuelta del Porvenir San Luis Stage 3.csv
# Processing 2023 Vuelta del Porvenir San Luis Stage 4.gpx...
# Saved to data/gpx_parsed\2023 Vuelta del Porvenir San Luis Stage 4.csv
# Processing 2023 Vuelta del Porvenir San Luis Stage 5.gpx...
# Saved to data/gpx_parsed\2023 Vuelta del Porvenir San Luis Stage 5.csv
# Processing 2023 Vuelta Espana Femenina Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Espana Femenina Stage 1.csv
# Processing 2023 Vuelta Espana Femenina Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Espana Femenina Stage 2.csv
# Processing 2023 Vuelta Espana Femenina Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Espana Femenina Stage 3.csv
# Processing 2023 Vuelta Espana Femenina Stage 4.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Espana Femenina Stage 4.csv
# Processing 2023 Vuelta Espana Femenina Stage 5.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Espana Femenina Stage 5.csv
# Processing 2023 Vuelta Espana Femenina Stage 6.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Espana Femenina Stage 6.csv
# Processing 2023 Vuelta Espana Femenina Stage 7.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Espana Femenina Stage 7.csv
# Processing 2023 Vuelta Extremadura Feminas Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Extremadura Feminas Stage 1.csv
# Processing 2023 Vuelta Extremadura Feminas Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Extremadura Feminas Stage 2.csv
# Processing 2023 Vuelta Extremadura Feminas Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Extremadura Feminas Stage 3.csv
# Processing 2023 Vuelta Internacional Femenina a Costa Rica.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Internacional Femenina a Costa Rica.csv
# Processing 2023 Vuelta Junior a la Ribera del Duero Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Junior a la Ribera del Duero Stage 1.csv
# Processing 2023 Vuelta Junior a la Ribera del Duero Stage 2-1.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Junior a la Ribera del Duero Stage 2-1.csv
# Processing 2023 Vuelta Junior a la Ribera del Duero Stage 2-2.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Junior a la Ribera del Duero Stage 2-2.csv
# Processing 2023 Vuelta Junior a la Ribera del Duero Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Vuelta Junior a la Ribera del Duero Stage 3.csv
# Processing 2023 Walmart Joe Martin Stage Race Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Walmart Joe Martin Stage Race Stage 1.csv
# Processing 2023 Walmart Joe Martin Stage Race Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Walmart Joe Martin Stage Race Stage 2.csv
# Processing 2023 Walmart Joe Martin Stage Race Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Walmart Joe Martin Stage Race Stage 3.csv
# Processing 2023 Walmart Joe Martin Stage Race Stage 4.gpx...
# Saved to data/gpx_parsed\2023 Walmart Joe Martin Stage Race Stage 4.csv
# Processing 2023 Watersley Junior Challenge Prologue.gpx...
# Saved to data/gpx_parsed\2023 Watersley Junior Challenge Prologue.csv
# Processing 2023 Watersley Junior Challenge Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Watersley Junior Challenge Stage 1.csv
# Processing 2023 Watersley Junior Challenge Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Watersley Junior Challenge Stage 2.csv
# Processing 2023 Watersley Ladies Challenge Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Watersley Ladies Challenge Stage 1.csv
# Processing 2023 Watersley Ladies Challenge Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Watersley Ladies Challenge Stage 2.csv
# Processing 2023 Watersley Ladies Challenge Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Watersley Ladies Challenge Stage 3.csv
# Processing 2023 Watersley Womens Challenge Stage 1.gpx...
# Saved to data/gpx_parsed\2023 Watersley Womens Challenge Stage 1.csv
# Processing 2023 Watersley Womens Challenge Stage 2.gpx...
# Saved to data/gpx_parsed\2023 Watersley Womens Challenge Stage 2.csv
# Processing 2023 Watersley Womens Challenge Stage 3.gpx...
# Saved to data/gpx_parsed\2023 Watersley Womens Challenge Stage 3.csv
# Processing 2023 Women Cycling Pro Costa De Almeria.gpx...
# Saved to data/gpx_parsed\2023 Women Cycling Pro Costa De Almeria.csv
# Processing 2023 Womens Cycling Grand Prix Stuttgart & Region.gpx...
# Saved to data/gpx_parsed\2023 Womens Cycling Grand Prix Stuttgart & Region.csv
# Processing 2023 Youngster Coast Challenge.gpx...
# Saved to data/gpx_parsed\2023 Youngster Coast Challenge.csv
# Processing 2023 ZLM Omloop der Kempen Ladies.gpx...
# Saved to data/gpx_parsed\2023 ZLM Omloop der Kempen Ladies.csv
# Processing 2023 ZLM Tour Prologue.gpx...
# Saved to data/gpx_parsed\2023 ZLM Tour Prologue.csv
# Processing 2023 ZLM Tour Stage 1.gpx...
# Saved to data/gpx_parsed\2023 ZLM Tour Stage 1.csv
# Processing 2023 ZLM Tour Stage 2.gpx...
# Saved to data/gpx_parsed\2023 ZLM Tour Stage 2.csv
# Processing 2023 ZLM Tour Stage 3.gpx...
# Saved to data/gpx_parsed\2023 ZLM Tour Stage 3.csv
# Processing 2023 ZLM Tour Stage 4.gpx...
# Saved to data/gpx_parsed\2023 ZLM Tour Stage 4.csv
# All GPX files have been processed.

# %%
import os
import time
import gpxpy
import pandas as pd
import numpy as np
from haversine import haversine, Unit
import cProfile
import pstats

# Directory containing GPX files
gpx_dir = "data/gpx_files"
output_dir = "data/gpx_parsed"

# Ensure the output directory exists
os.makedirs(output_dir, exist_ok=True)

# Function to calculate haversine distance
def haversine_distance(lat1, lon1, lat2, lon2):
    return haversine((lat1, lon1), (lat2, lon2), unit=Unit.METERS)

# Function to parse metadata using ElementTree
def parse_metadata(file_path):
    tree = ET.parse(file_path)
    root = tree.getroot()
    namespace = {"default": "http://www.topografix.com/GPX/1/1"}

    # Extract link
    link = root.find("default:metadata/default:author/default:link", namespace)
    link = link.attrib["href"] if link is not None else "No link"

    return link

# Avoids haversine package
def fast_haversine_np(df):
    lat = np.radians(df["latitude"].to_numpy())
    lon = np.radians(df["longitude"].to_numpy())
    
    dlat = lat[1:] - lat[:-1]
    dlon = lon[1:] - lon[:-1]

    a = np.sin(dlat / 2.0) ** 2 + np.cos(lat[:-1]) * np.cos(lat[1:]) * np.sin(dlon / 2.0) ** 2
    c = 2 * np.arcsin(np.sqrt(a))
    R = 6371000  # Earth radius in meters
    dist = R * c

    return np.insert(dist, 0, 0)

# Function to parse a single GPX file and calculate derived fields
def parse_gpx_file(file_path):
    
    # Extract the file name (without extension) as the name
    name = os.path.splitext(os.path.basename(file_path))[0]
    # Parse metadata
    link = parse_metadata(file_path)

    # Parse track points using gpxpy
    with open(file_path, 'r') as gpx_file:
        gpx = gpxpy.parse(gpx_file)

    route_info = []
    for track in gpx.tracks:
        for segment in track.segments:
            for point in segment.points:
                route_info.append({
                    "latitude": point.latitude,
                    "longitude": point.longitude,
                    "elevation": point.elevation,
                    "time": point.time,
                    "name": name,
                    "link": link
                })

    # Convert to DataFrame
    route_df = pd.DataFrame(route_info)

    # Profile the Haversine calculation and cumsum
    start_time = time.time()
    route_df["distance"] = fast_haversine_np(route_df)
    route_df['cum_distance'] = route_df['distance'].cumsum()
    elapsed_time = time.time() - start_time
    print(f"Time for Haversine and cumsum: {elapsed_time:.4f} seconds")

    return route_df

# # Example of profiling function
# def profile_script():
#     for file_path in os.listdir(gpx_dir)[:10]:  # Process first 10 GPX files
#         file_path = os.path.join(gpx_dir, file_path)
#         if file_path.endswith('.gpx'):
#             print(f"Processing {file_path}...")
#             parse_gpx_file(file_path)

# # Start profiling
# cProfile.run('profile_script()', 'profile_output.stats')

# # Print profiling results
# stats = pstats.Stats('profile_output.stats')
# stats.strip_dirs()
# stats.sort_stats('cumtime')  # Sort by cumulative time
# stats.print_stats(10)  # Print top 10 functions by cumulative time
# Out:
# Processing data/gpx_files\2017 4 Jours de Dunkerque .gpx...
# Time for Haversine and cumsum: 0.0048 seconds
# Processing data/gpx_files\2017 99a Coppa Bernocchi - 42o GP BPM.gpx...
# Time for Haversine and cumsum: 0.0136 seconds
# Processing data/gpx_files\2017 Abu Dhabi Tour Stage 1.gpx...
# Time for Haversine and cumsum: 0.0000 seconds
# Processing data/gpx_files\2017 Abu Dhabi Tour Stage 2.gpx...
# Time for Haversine and cumsum: 0.0000 seconds
# Processing data/gpx_files\2017 Abu Dhabi Tour Stage 3.gpx...
# Time for Haversine and cumsum: 0.0000 seconds
# Processing data/gpx_files\2017 Abu Dhabi Tour Stage 4.gpx...
# Time for Haversine and cumsum: 0.0000 seconds
# Processing data/gpx_files\2017 ACC Asian Road Championships - ITT.gpx...
# Time for Haversine and cumsum: 0.0000 seconds
# Processing data/gpx_files\2017 ACC Asian Road Championships - TTT.gpx...
# Time for Haversine and cumsum: 0.0000 seconds
# Processing data/gpx_files\2017 ACC Asian Road Championships.gpx...
# Time for Haversine and cumsum: 0.0000 seconds
# Processing data/gpx_files\2017 Amgen Tour of California Stage 1.gpx...
# Time for Haversine and cumsum: 0.0000 seconds
# Fri Apr 11 10:47:44 2025    profile_output.stats
#
#          6432170 function calls (6384075 primitive calls) in 5.209 seconds
#
#    Ordered by: cumulative time
#    List reduced from 495 to 10 due to restriction <10>
#
#    ncalls  tottime  percall  cumtime  percall filename:lineno(function)
#         1    0.000    0.000    5.202    5.202 {built-in method builtins.exec}
#         1    0.000    0.000    5.202    5.202 <string>:1(<module>)
#         1    0.009    0.009    5.198    5.198 1303264164.py:86(profile_script)
#        10    0.194    0.019    5.188    0.519 1303264164.py:49(parse_gpx_file)
#        10    0.022    0.002    4.224    0.422 __init__.py:21(parse)
#        10    0.001    0.000    4.186    0.419 parser.py:87(parse)
#  47816/10    0.948    0.000    3.941    0.394 gpxfield.py:559(gpx_fields_from_xml)
#     60/40    0.035    0.001    3.941    0.099 gpxfield.py:233(from_xml)
#   1099248    0.576    0.000    2.438    0.000 gpxfield.py:180(from_xml)
#     47786    0.030    0.000    1.467    0.000 gpxfield.py:121(from_string)
